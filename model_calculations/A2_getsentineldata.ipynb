# %% [markdown]
# ## AGAME Workflow. Get sentinel data

# %%
import ee
import pandas as pd
import os
from GppTools import Gpp as gpp

# ee.Authenticate() #For authentifications we require a Google Account registered in GEE (https://earthengine.google.com/)
ee.Initialize()

# %%
dgpp = gpp()
dgpp.collection = 'COPERNICUS/S2_SR_HARMONIZED'            #Multi-spectral surface reflectances (https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR)
dgpp.year_list = [2017,2018,2019,2020,2021,2022,2023,2024]
dgpp.max_cloud_coverage   = 30
dgpp.local_cloud_coverage = 100
dgpp.ndviMask = -100
dgpp.mndviMask = -100
dgpp.bands = ['NDVI','EVI','EVI2','CLr','MNDVI','MNDWI','LSWI','NDII', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12']
dgpp.crs = 'EPSG:32632'
dgpp.resolution = 10
dgpp.outputdir = r'D:\Proyectos2024\Agame\Output\sentinel2'
output_directory = r'D:\Proyectos2024\Agame\Output\sites_selection'

df = pd.read_csv(os.path.join(output_directory,'sites_table_filtered_4y.csv'), sep=';')

# %%
for index, row in df.iterrows():

    id = row['sites_ids']
    print('Process for: ', id,'\n')

    dgpp.longitude = row['lon']
    dgpp.latitude = row['lat']
    dgpp.ID = row['sites_ids']
    fetch = row['FETCH_70']
    lon_lat         =  [dgpp.longitude, dgpp.latitude]
    point = ee.Geometry.Point(lon_lat)
    aoi  = point.buffer(fetch)

    try:
        S2_VI_df, df_VI_export_processed = dgpp.calculate_VI_with_area_simplified_over_time(dgpp.collection,dgpp.year_list, aoi, dgpp.longitude, dgpp.latitude, dgpp.max_cloud_coverage, dgpp.local_cloud_coverage, dgpp.ndviMask, dgpp.mndviMask, dgpp.bands, dgpp.crs, dgpp.resolution, dgpp.ID, dgpp.outputdir)                                                                

    except Exception as e:
        print(f"First function failed with error: {e}")
        S2_VI_df, df_VI_export_processed = dgpp.calculate_VI_with_area_simplified(dgpp.collection,dgpp.year_list, aoi, dgpp.longitude, dgpp.latitude, dgpp.max_cloud_coverage, dgpp.local_cloud_coverage, dgpp.ndviMask, dgpp.mndviMask, dgpp.bands, dgpp.crs, dgpp.resolution, dgpp.ID, dgpp.outputdir)
# Out:
# Process for:  IT-SR2
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 107
# The filtered size of the collection is 60
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 280
# The filtered size of the collection is 140
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 285
# The filtered size of the collection is 135
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 292
# The filtered size of the collection is 142
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 292
# The filtered size of the collection is 142
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 288
# The filtered size of the collection is 132
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 290
# The filtered size of the collection is 125
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 198
# The filtered size of the collection is 74
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  SE-Htm
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 101
# The filtered size of the collection is 19
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 286
# The filtered size of the collection is 94
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 294
# The filtered size of the collection is 62
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 294
# The filtered size of the collection is 76
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 294
# The filtered size of the collection is 67
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 286
# The filtered size of the collection is 62
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 294
# The filtered size of the collection is 58
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 198
# The filtered size of the collection is 36
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  IT-Tor
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 52
# The filtered size of the collection is 19
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 45
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 67
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 147
# The filtered size of the collection is 67
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 59
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 144
# The filtered size of the collection is 68
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 65
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 97
# The filtered size of the collection is 33
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  IT-Niv
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 26
# The filtered size of the collection is 8
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 21
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 75
# The filtered size of the collection is 36
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 74
# The filtered size of the collection is 33
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 31
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 37
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 31
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 48
# The filtered size of the collection is 19
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  FR-Mej
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 52
# The filtered size of the collection is 14
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 142
# The filtered size of the collection is 42
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 39
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 45
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 41
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 145
# The filtered size of the collection is 42
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 147
# The filtered size of the collection is 31
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 98
# The filtered size of the collection is 18
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  DE-Msr
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 103
# The filtered size of the collection is 30
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 284
# The filtered size of the collection is 79
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 286
# The filtered size of the collection is 89
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 290
# The filtered size of the collection is 100
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 290
# The filtered size of the collection is 86
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 288
# The filtered size of the collection is 95
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 290
# The filtered size of the collection is 70
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 196
# The filtered size of the collection is 43
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  DE-Har
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 27
# The filtered size of the collection is 7
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 74
# The filtered size of the collection is 19
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 74
# The filtered size of the collection is 17
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 74
# The filtered size of the collection is 23
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 14
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 24
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 74
# The filtered size of the collection is 16
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 49
# The filtered size of the collection is 4
#
#
# First function failed with error: Element.propertyNames: Parameter 'element' is required.
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 515
# The filtered size of the collection is 124
#
#
# The maximun cloud coverage in the area is: 100
# The original size of the collection is 124
# The filtered size of the collection is 124
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  DE-Hai
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 100
# The filtered size of the collection is 25
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 289
# The filtered size of the collection is 82
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 293
# The filtered size of the collection is 66
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 296
# The filtered size of the collection is 71
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 295
# The filtered size of the collection is 60
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 286
# The filtered size of the collection is 66
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 292
# The filtered size of the collection is 47
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 194
# The filtered size of the collection is 34
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  CH-Dav
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 26
# The filtered size of the collection is 10
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 71
# The filtered size of the collection is 28
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 72
# The filtered size of the collection is 23
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 33
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 31
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 71
# The filtered size of the collection is 31
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 23
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 49
# The filtered size of the collection is 10
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  SE-Svb
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 58
# The filtered size of the collection is 15
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 168
# The filtered size of the collection is 59
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 175
# The filtered size of the collection is 58
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 173
# The filtered size of the collection is 52
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 179
# The filtered size of the collection is 50
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 177
# The filtered size of the collection is 38
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 178
# The filtered size of the collection is 43
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 130
# The filtered size of the collection is 26
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  SE-Nor
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 84
# The filtered size of the collection is 25
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 253
# The filtered size of the collection is 92
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 268
# The filtered size of the collection is 76
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 274
# The filtered size of the collection is 92
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 274
# The filtered size of the collection is 78
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 270
# The filtered size of the collection is 71
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 272
# The filtered size of the collection is 60
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 192
# The filtered size of the collection is 47
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  FR-Fon
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 24
# The filtered size of the collection is 5
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 71
# The filtered size of the collection is 20
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 71
# The filtered size of the collection is 19
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 25
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 21
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 28
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 74
# The filtered size of the collection is 12
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 48
# The filtered size of the collection is 4
#
#
# First function failed with error: Element.propertyNames: Parameter 'element' is required.
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 503
# The filtered size of the collection is 133
#
#
# The maximun cloud coverage in the area is: 100
# The original size of the collection is 133
# The filtered size of the collection is 133
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  FR-Bil
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 26
# The filtered size of the collection is 11
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 72
# The filtered size of the collection is 26
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 75
# The filtered size of the collection is 32
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 29
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 27
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 20
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 73
# The filtered size of the collection is 15
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 49
# The filtered size of the collection is 9
#
#
# First function failed with error: Element.propertyNames: Parameter 'element' is required.
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 514
# The filtered size of the collection is 169
#
#
# The maximun cloud coverage in the area is: 100
# The original size of the collection is 169
# The filtered size of the collection is 158
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  FI-Hyy
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 84
# The filtered size of the collection is 16
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 233
# The filtered size of the collection is 85
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 250
# The filtered size of the collection is 63
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 246
# The filtered size of the collection is 60
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 256
# The filtered size of the collection is 71
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 256
# The filtered size of the collection is 59
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 250
# The filtered size of the collection is 56
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 182
# The filtered size of the collection is 54
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  DE-Tha
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 51
# The filtered size of the collection is 8
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 143
# The filtered size of the collection is 45
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 145
# The filtered size of the collection is 37
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 146
# The filtered size of the collection is 51
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 145
# The filtered size of the collection is 25
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 144
# The filtered size of the collection is 30
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 145
# The filtered size of the collection is 21
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 98
# The filtered size of the collection is 21
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  DE-HoH
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 51
# The filtered size of the collection is 10
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 142
# The filtered size of the collection is 44
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 147
# The filtered size of the collection is 37
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 147
# The filtered size of the collection is 35
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 147
# The filtered size of the collection is 24
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 143
# The filtered size of the collection is 24
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 147
# The filtered size of the collection is 24
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 98
# The filtered size of the collection is 15
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  BE-Vie
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 24
# The filtered size of the collection is 2
#
#
# First function failed with error: Element.propertyNames: Parameter 'element' is required.
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 505
# The filtered size of the collection is 114
#
#
# The maximun cloud coverage in the area is: 100
# The original size of the collection is 114
# The filtered size of the collection is 114
#
#
#        Exporting: Vegetation_indices.csv
#
#
# Process for:  BE-Bra
#
# Index: 0, Element: 2017
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 101
# The filtered size of the collection is 17
#
#
# Index: 1, Element: 2018
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 286
# The filtered size of the collection is 77
#
#
# Index: 2, Element: 2019
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 288
# The filtered size of the collection is 67
#
#
# Index: 3, Element: 2020
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 294
# The filtered size of the collection is 89
#
#
# Index: 4, Element: 2021
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 290
# The filtered size of the collection is 67
#
#
# Index: 5, Element: 2022
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 292
# The filtered size of the collection is 66
#
#
# Index: 6, Element: 2023
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 290
# The filtered size of the collection is 44
#
#
# Index: 7, Element: 2024
# The maximun cloud coverage in the image is: 30
# The original size of the collection is 195
# The filtered size of the collection is 22
#
#
#        Exporting: Vegetation_indices.csv
